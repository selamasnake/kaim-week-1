# %%
import sys
sys.path.append('../../scripts')
import financial_metric as fm

# %% [markdown]
# #### Financial Metrics with PyNance

# %%
financial_analysis = fm.FinancialMetirc

# %%
financial_analysis.calculate_financial_metric()
# Out:
# /Users/hazel/Desktop/Self Study/kiam8/kaim-week-1/.venv/lib/python3.12/site-packages/pynance/datasources/data_retriever.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if adj_close_data[-1] == 0:
# /Users/hazel/Desktop/Self Study/kiam8/kaim-week-1/.venv/lib/python3.12/site-packages/pynance/datasources/data_retriever.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if adj_close_data[-1] == 0:
# ...
